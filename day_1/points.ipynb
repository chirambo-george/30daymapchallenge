# %% [markdown]
# DAY 1: POINTS

# %%
# importing libraries
import geopandas as gpd
import folium

# %%
# connecting to the data
data = gpd.read_file('data/mwi_hltfacp_health_fac_HISP.shp')

# %%
data.head()
# Out:
#      TYPE         NAME FACILITY_I  DISTRICT                    ADDRESS  \
# 0  Clinic  Area 25 BLM       None  Lilongwe    P.O. Box 1854\nLilongwe
# 1  Clinic   Balaka BLM       None    Balaka              Private Bag 6
# 2  Clinic  Bvumbwe BLM       3126    Thyolo  P.O. Box 185\nBoxvumBoxwe
# 3  Clinic    Dedza BLM       None     Dedza               P.O. Box 307
# 4  Clinic     Dowa BLM       None      Dowa                       None
#
#    ROAD_ACCES COORD_SD COORD_SM COORD_SS         Y  ... YOUTH_FRIE FP_SER  \
# 0  Earth Fair       13       53    41.10 -13.89475  ...         no    yes
# 1      Tarmac       14       59    19.50 -14.98875  ...         no    yes
# 2      Tarmac       15       55    52.00 -15.93111  ...         no     no
# 3      Tarmac       14       22    34.50 -14.37625  ...         no     no
# 4      Tarmac       13       31    55.00 -13.53194  ...         no    yes
#
#   STDS_SERVI  UNDER5_SER LAB_SER  EPI NO4HRHS ON_CALL CATCH_POP  \
# ...

# %%
data['TYPE'].unique()
# Out:
# array(['Clinic', 'Health Centre', 'Rehabilitation Centr', 'Hospital',
#        'Maternity', 'Dispensary', 'Rural Hospital', 'District Hospital',
#        'Central Hospital', 'Mental Hospital', 'Voluntary Counsellin'],
#       dtype=object)

# %%
def show_map():

    # initializing Map object, location, zoom and map style
    m = folium.Map(
        location=[37.77, -122.42], 
        zoom_start= 12, 
        tiles = 'https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png', 
        attr = '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>'
    )

    # since we have a lot of points we want to use the MarkCluster plugin
    # to avoid clutter
    # points = plugins.MarkerCluster()

    # icon = folium.plugins.BeautifyIcon(
    #     icon='arrow-down', 
    #     iconShape='marker',
    #     textColor='red',
    #     backgroundColor='yellow')

    for lon, lat, label in zip(data['Longitude'], data['Latitude'], data['Incident Category']):
        
        folium.Marker(
            location=[lat, lon],
            icon = folium.Icon(icon='star', color='red'),
            popup = label
            
            
        ).add_to(points)
        
    # adding our points to the map
        
    points.add_to(m)
    map__  = st_folium(m, width=725)

show_map()
